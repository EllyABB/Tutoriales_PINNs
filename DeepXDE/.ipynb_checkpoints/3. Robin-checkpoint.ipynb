# %% [markdown]
# # Robin Boundary Conditions
#
# Tomamos la misma ecuación de poisson en el mismo intervalo:
# $$\frac{d^2u}{dx^2}=2,\qquad x\in[-1,1]$$
#
# La condición de **Dirichlet** en una frontera es:
# $$u(-1)=0$$
#
# Y la condición de **Robin** en la frontera derecha:
#
# $$\left.\frac{du}{dx}\right|_{u=1}=u$$
#
#
# La solucíon exacta es la misma:
# $$u(x)=(x+1)^2$$
#
# Estas condiciones de frontera  (Junto con la BC periódica) son tareas más críticas que aveces incluso pueden introducir inestabilidades en el entrenamiento lo que puede llebar a una solucion de la red debil.

# %%
import deepxde as dde
import numpy as np
import matplotlib.pyplot as plt

dde.backend.backend_name = "pytorch"
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.

# %%
import torch as tr

# %%
def pde(x, y):
    dy_xx = dde.grad.hessian(y,x)
    return dy_xx -2

# %%
## Exact solution
def func(x):
    return (x+1)**2

# %% [markdown]
# ### Dirichlet

# %%
def boundary_value1(x):
    return 0 #Sets u=0

def boundary_1(x,on_boundary):
    return on_boundary and dde.utils.isclose(x[0],-1)

# %% [markdown]
# ### Robin

# %%
def boundary_flux_r(x,y):
    return y #Sets du/dx=u at all x=1

def boundary_r(x,on_boundary):
    return on_boundary and dde.utils.isclose(x[0],1)

# %% [markdown]
# ### Main PINN Model

# %%
geom = dde.geometry.Interval(-1,1)

# %%
bc_1=dde.icbc.DirichletBC(geom, boundary_value1,boundary_1)
bc_r=dde.icbc.RobinBC(geom, boundary_flux_r,boundary_r)

# %%
## Data model:
data = dde.data.PDE(geom,
                    pde,
                    [bc_1,bc_r],
                    16,         # No of collocation points
                    2,
                    solution=func,
                    num_test=100
                   )

# %%
layer_size = [1] + [50]*3 + [1]
# [1]: x input layer
# [50]*3: 3 capas ocultas con 50 neuronas
# [1]: y output layer
activation = "tanh"
initializer = "Glorot uniform"

## FNN Fully conected neural network
net = dde.nn.FNN(layer_size,
                activation,
                initializer
                )

# %%
model = dde.Model(data,net)

model.compile("adam",lr=1e-3,metrics=["l2 relative error"])

losshistory, train_state = model.train(iterations = 1000)
# Out:
# Compiling model...
# 'compile' took 1.037042 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [4.00e+00, 7.28e-03, 6.33e-05]    [4.00e+00, 7.28e-03, 6.33e-05]    [9.82e-01]
# 1000      [4.27e-05, 6.40e-10, 2.19e-10]    [3.39e-05, 6.40e-10, 2.19e-10]    [6.69e-04]
#
# Best model at step 1000:
#   train loss: 4.27e-05
#   test loss: 3.39e-05
#   test metric: [6.69e-04]
#
# 'train' took 2.776723 s

# %%
x_values_pinn = np.linspace(-1,1,100).reshape(-1,1)
y_pred        = model.predict(x_values_pinn)

x_values_exact = np.linspace(-1,1,20).reshape(-1,1)
y_exact        = func(x_values_exact)


plt.figure(figsize=(6,4))
plt.plot(x_values_exact,y_exact,'ob',label="Solución Exacta")

plt.plot(x_values_pinn,y_pred,'--r',label="Predicción PINN")

plt.xlabel("$x$")
plt.ylabel("$u(x)$")
plt.title("PINN Prediction vrs Exact Solution")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # <code>error</code>  Method of OperatorBC

# %%
X_test = tr.tensor(np.array([[1.0]]), dtype = tr.float32, requires_grad=True)#.to("cuda")

net = model.net
outputs = net(X_test)

residual_r = bc_r.error(
    X_test.detach().numpy(),      # <-- Se convierte en un arreglo de numpy
    X_test,
    outputs,
    0,
    len(X_test),
)

mse_residual_r = tr.mean(residual_r**2)


print(f"Residual for RobiBC:{residual_r.detach().numpy()}")
print(f"MSE of Boundary residual: {mse_residual_r.item()}")
# Out:
# Residual for RobiBC:[[1.4781952e-05]]
# MSE of Boundary residual: 2.18506102100946e-10
